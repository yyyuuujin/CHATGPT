# %% [markdown]
# # 로드

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Chat집pt/csv/전체아파트_병원학교시군구브랜드공원출근자평.csv')
df.head()
# Out:
#                           아파트명              법정동주소         위도         경도  세대수  \
# 0  인천 영종국제도시 A47BL 호반써밋 스카이센트럴  인천시 중구 중산동 1888-1  37.495534  126.56693  534
# 1  인천 영종국제도시 A47BL 호반써밋 스카이센트럴  인천시 중구 중산동 1888-1  37.495534  126.56693  534
# 2  인천 영종국제도시 A47BL 호반써밋 스카이센트럴  인천시 중구 중산동 1888-1  37.495534  126.56693  534
# 3  인천 영종국제도시 A47BL 호반써밋 스카이센트럴  인천시 중구 중산동 1888-1  37.495534  126.56693  534
# 4  인천 영종국제도시 A47BL 호반써밋 스카이센트럴  인천시 중구 중산동 1888-1  37.495534  126.56693  534
#
#    임대세대수   최고층   최저층  최대공급면적  최소공급면적  ...  중등거리     중등이름  고등거리      고등이름  \
# 0    0.0  25.0  22.0  111.62   98.67  ...  0.48  인천중산중학교  0.36  인천중산고등학교
# 1    0.0  25.0  22.0  111.62   98.67  ...  0.48  인천중산중학교  0.36  인천중산고등학교
# 2    0.0  25.0  22.0  111.62   98.67  ...  0.48  인천중산중학교  0.36  인천중산고등학교
# 3    0.0  25.0  22.0  111.62   98.67  ...  0.48  인천중산중학교  0.36  인천중산고등학교
# 4    0.0  25.0  22.0  111.62   98.67  ...  0.48  인천중산중학교  0.36  인천중산고등학교
#
#         시군구  브랜드이름  공원거리   공원이름    출퇴근자   평
# ...

# %%
df = df[['아파트명', '평', '방수', '욕실수', '지하철역', '지하철역_거리', '분양가(만원)', '시군구']]
df
# Out:
#                              아파트명   평   방수  욕실수 지하철역  지하철역_거리  분양가(만원)  \
# 0     인천 영종국제도시 A47BL 호반써밋 스카이센트럴  34  4.0  2.0  영종역   4.1915    38940
# 1     인천 영종국제도시 A47BL 호반써밋 스카이센트럴  33  3.0  2.0  영종역   4.1915    38820
# 2     인천 영종국제도시 A47BL 호반써밋 스카이센트럴  34  4.0  2.0  영종역   4.1915    38620
# 3     인천 영종국제도시 A47BL 호반써밋 스카이센트럴  34  4.0  2.0  영종역   4.1915    37990
# 4     인천 영종국제도시 A47BL 호반써밋 스카이센트럴  30  3.0  2.0  영종역   4.1915    34990
# ...                           ...  ..  ...  ...  ...      ...      ...
# 3099                         가평자이  34  4.0  2.0  가평역   0.7599    35480
# 3100                         가평자이  32  3.0  2.0  가평역   0.7599    32320
# 3101                         가평자이  25  3.0  2.0  가평역   0.7599    25520
# 3102                         가평자이  24  3.0  2.0  가평역   0.7599    25420
# 3103                         가평자이  24  3.0  2.0  가평역   0.7599    24540
#
#            시군구
# 0     인천광역시 중구
# 1     인천광역시 중구
# 2     인천광역시 중구
# 3     인천광역시 중구
# 4     인천광역시 중구
# ...        ...
# ...

# %%
ui = df[df['시군구'] == '경기도 의정부시']
ui.head()
# Out:
#                아파트명   평   방수  욕실수 지하철역  지하철역_거리  분양가(만원)       시군구
# 1820  의정부역 리버카운티아파트  25  3.0  2.0  동오역   0.3268    40800  경기도 의정부시
# 1821  의정부역 리버카운티아파트  23  3.0  1.0  동오역   0.3268    39600  경기도 의정부시
# 1822  의정부역 리버카운티아파트  23  3.0  1.0  동오역   0.3268    36600  경기도 의정부시
# 1823  의정부역 리버카운티아파트  25  3.0  2.0  동오역   0.3268    34200  경기도 의정부시
# 1824  의정부역 리버카운티아파트  23  3.0  1.0  동오역   0.3268    33000  경기도 의정부시

# %%
gu = df[df['시군구'] == '경기도 구리시']
gu.head()
# Out:
#                아파트명   평   방수  욕실수 지하철역  지하철역_거리  분양가(만원)      시군구
# 2828     인창칸타빌더헤리티지  34  3.0  2.0  구리역   0.7640    60510  경기도 구리시
# 2829     인창칸타빌더헤리티지  30  3.0  2.0  구리역   0.7640    53810  경기도 구리시
# 2830     인창칸타빌더헤리티지  24  3.0  2.0  구리역   0.7640    43810  경기도 구리시
# 2831     인창칸타빌더헤리티지  24  3.0  2.0  구리역   0.7640    43610  경기도 구리시
# 2832  구리역 롯데캐슬 시그니처  37  3.0  2.0  구리역   1.3505    97900  경기도 구리시

# %%
ui['지하철역'].unique()
# Out:
# array(['동오역', '의정부중앙역', '의정부역', '범골역', '가능역', '탑석역', '흥선역', '의정부시청역'],
#       dtype=object)

# %% [markdown]
# # 지하철역에 가까운

# %%
# df.loc[df['지하철역'] == '까치울역', '지하철역'] = '의정부역'

# %%
ui[ui['지하철역'] == '탑석역']
# Out:
#                        아파트명   평   방수  욕실수 지하철역  지하철역_거리  분양가(만원)       시군구
# 1860               힐스테이트 탑석  35  3.0  2.0  탑석역   0.4799    62810  경기도 의정부시
# 1861               힐스테이트 탑석  35  3.0  2.0  탑석역   0.4799    62260  경기도 의정부시
# 1862               힐스테이트 탑석  32  3.0  2.0  탑석역   0.4799    57750  경기도 의정부시
# 1863               힐스테이트 탑석  32  3.0  2.0  탑석역   0.4799    57360  경기도 의정부시
# 1864               힐스테이트 탑석  26  3.0  2.0  탑석역   0.4799    46280  경기도 의정부시
# 1865               힐스테이트 탑석  26  3.0  2.0  탑석역   0.4799    46010  경기도 의정부시
# 1866               힐스테이트 탑석  26  3.0  2.0  탑석역   0.4799    45930  경기도 의정부시
# 1880       의정부 고산 수자인 디에스티지  46  4.0  2.0  탑석역   1.5283    53300  경기도 의정부시
# 1881       의정부 고산 수자인 디에스티지  38  4.0  2.0  탑석역   1.5283    47500  경기도 의정부시
# 1882       의정부 고산 수자인 디에스티지  33  3.0  2.0  탑석역   1.5283    42000  경기도 의정부시
# 1883  의정부 고산 수자인 디에스티지 C1BL  32  4.0  2.0  탑석역   2.1926    39000  경기도 의정부시
# ...

# %% [markdown]
# # 아파트명 확인용

# %%
ui[ui['아파트명'] == '대가트라움(의정부)']
# Out:
#             아파트명   평   방수  욕실수    지하철역  지하철역_거리  분양가(만원)       시군구
# 1829  대가트라움(의정부)  26  3.0  2.0  의정부중앙역   0.3096    27500  경기도 의정부시
# 1830  대가트라움(의정부)  26  3.0  2.0  의정부중앙역   0.3096    27000  경기도 의정부시
# 1831  대가트라움(의정부)  26  3.0  2.0  의정부중앙역   0.3096    26900  경기도 의정부시
# 1832  대가트라움(의정부)  25  3.0  2.0  의정부중앙역   0.3096    26900  경기도 의정부시

"의정부역 월드메르디앙 스마트시티""28""3.0""2.0""흥선역""0.211""42700""경기도 의정부시"
"의정부역 월드메르디앙 스마트시티""28""3.0""2.0""흥선역""0.211""42200""경기도 의정부시"
"의정부 롯데캐슬 골드포레""33""3.0""2.0""의정부시청역""0.6969""45590""경기도 의정부시"
"의정부 롯데캐슬 골드포레""33""3.0""2.0""의정부시청역""0.6969""45520""경기도 의정부시"
"의정부 롯데캐슬 골드포레""34""3.0""2.0""의정부시청역""0.6969""44950""경기도 의정부시"
"의정부 롯데캐슬 골드포레""24""3.0""2.0""의정부시청역""0.6969""33460""경기도 의정부시"
"의정부 롯데캐슬 골드포레""24""3.0""2.0""의정부시청역""0.6969""32770""경기도 의정부시"
"의정부 롯데캐슬 골드포레""16""1.0""1.0""의정부시청역""0.6969""20440""경기도 의정부시"
"가능역 하우스토리 리버블리스""30""3.0""2.0""흥선역""0.8129""47030""경기도 의정부시"
"가능역 하우스토리 리버블리스""27""3.0""2.0""흥선역""0.8129""44600""경기도 의정부시"
"가능역 하우스토리 리버블리스""24""3.0""2.0""흥선역""0.8129""41560""경기도 의정부시"
"가능역 하우스토리 리버블리스""25""3.0""2.0""흥선역""0.8129""41560""경기도 의정부시"
"가능역 하우스토리 리버블리스""22""3.0""2.0""흥선역""0.8129""38270""경기도 의정부시"
"가능역 하우스토리 리버블리스""22""3.0""2.0""흥선역""0.8129""38270""경기도 의정부시"

# %%
a = pd.read_csv('/content/drive/MyDrive/Chat집pt/csv/전체아파트_병원학교시군구브랜드공원출근자평.csv')
a['지하철명'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '지하철명'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import csv
import json

a = pd.read_csv('/content/drive/MyDrive/Chat집pt/csv/전체아파트_병원학교시군구브랜드공원출근자평.csv')
aa = a.loc[(a['분양가(만원)'] < 46000) &  (a['법정동주소'].str.contains('의정부')) | (a['법정동주소'].str.contains('구리'))][['아파트명', '법정동주소','세대수', '세대평균_주차대수', '공급면적', '방수', '욕실수', '지하철역_거리', '공원거리', '초등거리','출퇴근자', '평', '지하철역', '시군구', '분양가(만원)']]
lst = ['''Let's think step by step
* 방에 대한 질문이 있을 경우 평수를 9로 나눈 값을 대략적인 방의 개수로 안내
예시)
- 24평: 대략 2-3개의 방
- 30평: 대략 3-4개의 방
- 34평: 대략 3-4개의 방
*욕실에 대한 질문이 있을 경우 평수를 12로 나눈 값을 대략적인 욕실의 개수로 안내
'''.replace('\n',' ')]

for i in aa['지하철역'].unique() :
  bb = aa.loc[a['지하철역'] == i]['아파트명']
  # lst.append(f"{i} 근처 아파트 : {list(set(bb))}")
  lst.append(f"{i} 출근자 수 : {int(list(set(aa.loc[a['지하철역'] == i]['출퇴근자']))[0]) // 90}명")
  # dic[f"{i} 근처 아파트"] = list(set(bb))
  # print(f"{i} 근처 아파트 : {list(set(bb))}")
  # dic['지하철역과의 거리'] =  list(aa.loc[a['아파트명'] == i]['지하철역_거리'].values)
  # dic[f'{i} 근처 아파트'] = list(set(bb)) , set(bb['지하철역_거리'].values)
  # lst.append(dic)

for i in aa['시군구'].unique() :
  lst.append(f"{i} 아파트 목록 : {list(set(aa.loc[a['시군구'] == i]['아파트명'].values))}")


for i in aa['아파트명'].unique() :
  dic, lst2 = {}, []

  zz = aa.loc[a['아파트명'] == i][['평', '방수', '욕실수', '지하철역_거리', '분양가(만원)', '법정동주소', '세대평균_주차대수', '지하철역']]
  dic['아파트 이름'] = i
  dic['주소'] = zz['법정동주소'].values[0]
  dic['지하철역과의 거리'] =  zz['지하철역_거리'].values[0]
  dic['세대평균 주차대수'] =  zz['세대평균_주차대수'].values[0]
  zz = aa.loc[a['아파트명'] == i][['평', '방수', '욕실수', '지하철역_거리', '분양가(만원)', '법정동주소', '세대평균_주차대수']].values
  dic2 = {}
  dic['정보'] = lst2
  for j in range(len(zz)) :
    dic2 = {}
    dic2['평'] = zz[j][0]
    # dic2['방 개수'] = int(zz[j][1])
    # dic2['욕실 개수'] = int(zz[j][2])
    dic2['분양가'] = int(zz[j][4] * 10000)
    lst2.append(dic2)
  lst.append(dic)
print(lst)
# lst, lz, dic  = ["Let's think step by step"], [], {}
# for i in aa['아파트명'].unique() :
#   zz = aa.loc[a['아파트명'] == i][['평', '방수', '욕실수', '지하철역_거리', '분양가(만원)', '법정동주소','세대수', '세대평균_주차대수', '공급면적','공원거리', '초등거리','출퇴근자']].values
#   lz.append(aa.loc[a['아파트명'] == i]['지하철역'].values)
#   ss = ''
#   ss += f'아파트 이름: {i} , '
#   ss += f"{i}의 세대수 : {list(set(aa.loc[a['아파트명'] == i]['세대수'].values))[0]},"
#   ss += f"{i}의 세대평균 주차대수 : {list(set(aa.loc[a['아파트명'] == i]['세대평균_주차대수'].values))[0]}대,"
#   ss += f"{i} 의 주소 :{list(set(aa.loc[a['아파트명'] == i]['법정동주소'].values))[0].split('(')[0]}, 구분 : ["
#   for j in range(len(zz)) :
#     print(zz[j][0])
    # ss += f'{int(zz[j][0])}평, 방 {int(zz[j][1])}개, 욕실 {int(zz[j][2])}개 , 분양가 {(int(zz[j][4])) // 10000 }억 {(int(zz[j][4])) // 10 }천만원 /'
  # dic['평수'] = list(map(int, zz['평'].values))
  # dic['방 수'] =  list(map(int, zz['방수'].values))
  # dic['욕실 수'] =  list(map(int, zz['욕실수'].values))
  # dic['분양가'] =  list(map(int, zz['분양가(만원)'].values * 10000))
  # dic['출근자'] =  f"{int(zz['출퇴근자'].values[0])}명"

  # lst.append(dic)
# lst
# Out:
# ["Let's think step by step * 방에 대한 질문이 있을 경우 평수를 9로 나눈 값을 대략적인 방의 개수로 안내 예시) - 24평: 대략 2-3개의 방 - 30평: 대략 3-4개의 방 - 34평: 대략 3-4개의 방 *욕실에 대한 질문이 있을 경우 평수를 12로 나눈 값을 대략적인 욕실의 개수로 안내 ", "동오역 근처 아파트 : ['의정부역 브라운스톤 리버뷰', '의정부역 리버카운티아파트']", '동오역 출근자 수 : 6228명', "의정부중앙역 근처 아파트 : ['이안 더 메트로(주상복합)', '의정부역 스카이자이', '대가트라움(의정부)']", '의정부중앙역 출근자 수 : 13675명', "의정부역 근처 아파트 : ['의정부역 월드메르디앙 웰라시티']", '의정부역 출근자 수 : 45811명', "범골역 근처 아파트 : ['의정부역 푸르지오 더 센트럴', '의정부역 진산엔월드메르디앙']", '범골역 출근자 수 : 7976명', "가능역 근처 아파트 : ['힐스테이트 의정부역']", '가능역 출근자 수 : 15137명', "탑석역 근처 아파트 : ['의정부 고산 수자인 디에스티지', '힐스테이트 탑석', '더샵 리듬시티', '의정부 고산 수자인 디에스티지 C3BL', '의정부 고산 수자인 디에스티지 C1BL']", '탑석역 출근자 수 : 3847명', "흥선역 근처 아파트 : ['의정부역 월드메르디앙 스마트시티', '가능역 하우스토리 리버블리스']", '흥선역 출근자 수 : 9644명', "의정부시청역 근처 아파트 : ['의정부 롯데캐슬 골드포레']", '의정부시청역 출근자 수 : 12481명', "구리역 근처 아파트 : ['인창칸타빌더헤리티지', '구리역 롯데캐슬 시그니처', '힐스테이트 구리역']", '구리역 출근자 수 : 23742명', "경기도 의정부시 아파트 목록 : ['의정부역 브라운스톤 리버뷰', '의정부 고산 수자인 디에스티지', '힐스테이트 의정부역', '의정부역 리버카운티아파트', '더샵 리듬시티', '의정부역 월드메
# ...

# %%
import csv
import json

a = pd.read_csv('/content/drive/MyDrive/Chat집pt/csv/전체아파트_병원학교시군구브랜드공원출근자평.csv')
aa = a.loc[(a['분양가(만원)'] < 46000) &  (a['전용면적'] < 85) & (a['법정동주소'].str.contains('의정부')) | (a['법정동주소'].str.contains('구리'))][['아파트명', '법정동주소','세대수', '세대평균_주차대수', '공급면적', '방수', '욕실수', '지하철역_거리', '공원거리', '초등거리','출퇴근자', '평', '지하철역', '시군구', '분양가(만원)']]
lst = ['''Let's think step by step
* 방에 대한 질문이 있을 경우 평수를 9로 나눈 값을 대략적인 방의 개수로 안내
예시)
- 24평: 대략 2-3개의 방
- 30평: 대략 3-4개의 방
- 34평: 대략 3-4개의 방
*욕실에 대한 질문이 있을 경우 평수를 12로 나눈 값을 대략적인 욕실의 개수로 안내
'''.replace('\n',' ')]

for i in aa['지하철역'].unique() :
  bb = aa.loc[a['지하철역'] == i]['아파트명']
  # lst.append(f"{i} 근처 아파트 : {list(set(bb))}")
  # lst.append(f"{i} 출근자 수 : {int(list(set(aa.loc[a['지하철역'] == i]['출퇴근자']))[0]) // 90}명")
  # dic[f"{i} 근처 아파트"] = list(set(bb))
  # print(f"{i} 근처 아파트 : {list(set(bb))}")
  # dic['지하철역과의 거리'] =  list(aa.loc[a['아파트명'] == i]['지하철역_거리'].values)
  # dic[f'{i} 근처 아파트'] = list(set(bb)) , set(bb['지하철역_거리'].values)
  # lst.append(dic)

# for i in aa['시군구'].unique() :
#   lst.append(f"{i} 아파트 목록 : {list(set(aa.loc[a['시군구'] == i]['아파트명'].values))}")

for i in aa['아파트명'].unique():
    dic, lst2 = {}, []

    zz = aa.loc[a['아파트명'] == i][['평', '방수', '욕실수', '지하철역_거리', '분양가(만원)', '법정동주소', '세대평균_주차대수', '지하철역']]
    dic['아파트 이름'] = i
    dic['주소'] = zz['법정동주소'].values[0]

    # '지하철역과의 거리' 값을 가져와서 역 이름을 추가하여 저장
    subway_distance = zz['지하철역_거리'].values[0]
    subway_name = zz['지하철역'].values[0]  # 가정: 역 이름은 '지하철역' 열에 들어있음
    dic[f'{subway_name}과의 거리'] = subway_distance  # 역 이름과 '역과의 거리'를 연결
    # dic['지하철역과의 거리'] = f'{subway_name}과의 거리'  # 역 이름과 '역과의 거리'를 연결

    # dic['세대평균 주차대수'] = zz['세대평균_주차대수'].values[0]

    zz = aa.loc[a['아파트명'] == i][['평', '방수', '욕실수', '지하철역_거리', '분양가(만원)', '법정동주소', '세대평균_주차대수']].values
    dic2 = {}
    dic['정보'] = lst2
    for j in range(len(zz)) :
      dic2 = {}
      dic2['평'] = zz[j][0]
      # dic2['방 개수'] = int(zz[j][1])
      # dic2['욕실 개수'] = int(zz[j][2])
      dic2['분양가'] = int(zz[j][4] * 10000)
      lst2.append(dic2)
    lst.append(dic)
print(lst)
# Out:
# ["Let's think step by step * 방에 대한 질문이 있을 경우 평수를 9로 나눈 값을 대략적인 방의 개수로 안내 예시) - 24평: 대략 2-3개의 방 - 30평: 대략 3-4개의 방 - 34평: 대략 3-4개의 방 *욕실에 대한 질문이 있을 경우 평수를 12로 나눈 값을 대략적인 욕실의 개수로 안내 ", {'아파트 이름': '의정부역 리버카운티아파트', '주소': '경기도 의정부시 호국로1346번길 12(의정부동, 리버카운티)', '동오역과의 거리': 0.3268, '정보': [{'평': 25, '분양가': 408000000}, {'평': 23, '분양가': 396000000}, {'평': 23, '분양가': 366000000}, {'평': 25, '분양가': 342000000}, {'평': 23, '분양가': 330000000}, {'평': 23, '분양가': 300000000}]}, {'아파트 이름': '이안 더 메트로(주상복합)', '주소': '경기도 의정부시 평화로567번길 15(의정부동, 이안더메트로)', '의정부중앙역과의 거리': 0.3549, '정보': [{'평': 28, '분양가': 437700000}, {'평': 29, '분양가': 436400000}, {'평': 28, '분양가': 436400000}]}, {'아파트 이름': '대가트라움(의정부)', '주소': '경기도 의정부시 의정부동 9-49', '의정부중앙역과의 거리': 0.3096, '정보': [{'평': 26, '분양가': 275000000}, {'평': 26, '분양가': 270000000}, {'평': 26, '분양가': 269000000}, {'평': 25, '분양가': 269000000}]}, {'아파트 이름': '의정부역 월드메르디앙 웰라시티', '주소': '경기도 의정부시 의정부동 487-2번지', '의정부역과의 거리': 0.3914, '정보': [{'평': 32, '분양가': 456000000}, {'평': 30, '분양가': 450000000}]}
# ...

# %%
aa['지하철역'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-392426d8bf86> in <cell line: 1>()
# ----> 1 aa['지하철역'].unique()
#
# NameError: name 'aa' is not defined

# %%
data = {
    "아파트 이름": "힐스테이트 의정부역",
    "주소": "경기도 의정부시 의정부동 240-130번지 일원",
    "가능역과의 거리": 0.4346,
    "세대평균 주차대수": 1.2,
    "정보": [
        {"평": 26, "분양가": 440000000}
    ]
}

# %%
["Let"s think step by step * 방에 대한 질문이 있을 경우 평수를 9로 나눈 값을 대략적인 방의 개수로 안내 예시) - 24평: 대략 2-3개의 방 - 30평: 대략 3-4개의 방 - 34평: 대략 3-4개의 방 *욕실에 대한 질문이 있을 경우 평수를 12로 나눈 값을 대략적인 욕실의 개수로 안내 ", "동오역 출근자 수 : 6228명", "의정부중앙역 출근자 수 : 13675명", "의정부역 출근자 수 : 45811명", "범골역 출근자 수 : 7976명", "가능역 출근자 수 : 15137명", "탑석역 출
 주차대수": 1.138983051, "정보": [{"평": 37, "분양가": 979000000}, {"평": 36, "분양가": 869000000}, {"평": 35, "분양가": 865000000}, {"평": 26, "분양가": 649000000}, {"평": 24, "분양가": 645000000}, {"평": 24, "분양가": 630000000}, {"평": 22, "분양가": 438000000}, {"평": 17, "분양가": 299000000}]}, {"아파트 이름": "힐스테이트 구리역", "주소": "경기도 구리시 수택동 532번지", "구리역과의 거리": 2.0683, "세대평균 주차대수": 1.21, "정보": [{"평": 33, "분양가": 800000000}, {"평": 30, "분양가": 736000000}, {"평": 30, "분양가": 735000000}, {"평": 25, "분양가": 610000000}, {"평": 25, "분양가": 607000000}, {"평": 25, "분양가": 604000000}]}]

# %%
loan_term_months = 50
loan_amount = 300000000 * 80
monthly_interest_rate = (0.04 / 12) / 100

loan_amount * (monthly_interest_rate * (1 + monthly_interest_rate)**loan_term_months) / ((1 + monthly_interest_rate)**loan_term_months - 1)
# Out:
# 40401999.96519086

# %%
def calculate_monthly_payment(loan_amount, annual_interest_rate, loan_term_months):
    # 월 이자율 계산
    monthly_interest_rate = (annual_interest_rate / 12) / 100

    # 월 상환액 계산
    monthly_payment = loan_amount * (monthly_interest_rate * (1 + monthly_interest_rate)**loan_term_months) / ((1 + monthly_interest_rate)**loan_term_months - 1)

    return monthly_payment

# 입력값 설정
loan_amount = 240000000  # 대출 원금 2억 4000만 원
annual_interest_rate = 4.0  # 연 이자율 4%
loan_term_months = 600  # 대출 기간 600개월 (50년)

# 월 상환액 계산
monthly_payment = calculate_monthly_payment(loan_amount, annual_interest_rate, loan_term_months)

year_payment = monthly_payment*12

print("매년 상환해야 하는 금액: {:.2f} 원".format(year_payment))



# # 입력값 설정
# 대출원금 = 240000000  # 대출 원금 2억 4000만 원
# 연_이자율 = 4.0  # 연 이자율 4%
# 대출기간 = 600  # 대출 기간 600개월 (50년)

# monthly_payment = 대출원금 * (((연이자율/12)/100) * (1 + ((연이자율/12)/100))**loan_term_months) / ((1 + ((연이자율/12)/100))**loan_term_months - 1)




# # 월 상환액 계산
# 월상환금액 = calculate_월상환금액(대출원금, 연_이자율, 대출기간)

# year_payment = 월상환금액*12

# print("매년 상환해야 하는 금액: {:.2f} 원".format(year_payment))
# Out:
# 매년 상환해야 하는 금액: 11108361.67 원

# %%
def calculate_월상환금액(대출금, 연이자율, 대출기간):
    대출금 = 분양가 * 0.8
    연이자율 = 4
    대출기간 = 600

    # 월 이자율 계산
    월이자율 = (연이자율 / 12) / 100

    # 월 상환액 계산
    월상환금액 = 대출금 * (월이자율 * (1 + 월이자율)**대출기간) / ((1 + 월이자율)**대출기간 - 1)
    연상환금액 = 대출금 * (월이자율 * (1 + 월이자율)**대출기간) / ((1 + 월이자율)**대출기간 - 1) * 12


    return 월상환금액

# 입력값 설정
대출금 = 240000000  # 대출 원금 2억 4000만 원
연이자율 = 4.0  # 연 이자율 4%
대출기간 = 600  # 대출 기간 600개월 (50년)

# 월 상환액 계산
월상환금액 = calculate_월상환금액(대출금, 연이자율, 대출기간)

year_payment = 월상환금액*12

print("매년 상환해야 하는 금액: {:.2f} 원".format(year_payment))
